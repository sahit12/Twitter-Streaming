# %%
import tweepy
from textblob import *

# %%
consumer_key = 'ckWNevb0CjTJkoGpWxGWi2Ngw'
consumer_secret = 'FcS881oFnDEsecFiR37ajvVXVm8nxW96X2THjXhwTn16WHNH7n'

access_token = '250539989-xXFekBQzCNB1LMtsAwKjSpYstA8nKfGJQqjFk2v0'
access_token_secret = 'PrRQxuvWqHVUbuH8ooQ5j6xd5lSf4uioC8KFNKNUufPbX'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
public_tweets = api.search('patna')
for tweet in public_tweets:
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.analyzer)
# Out:
# @DrmDnr @ECRlyHJP @PiyushGoyal sir athmalgola (atl) me train no-18183/84 tata danapur exp and 63221/22 patna mokama… https://t.co/z1NViZUANO
# ...
# RT @BloodDonorsIn: #Patna Need #Blood O+ve at PMCH. Call 7979851300 via @pshnkaj_kashyap #BloodMatters
# ...
# RT @UnsungBollywood: #HrithikRoshan makes teacher look sexy for #GQ best dressed party #Super30 #Patna #Bihari #AnandKumar https://t.co/CCV…
# ...
# Don't try to talk to me on no relationship shit because ian w/ it &amp; i'mma STEP Patna 😂😂 I don't believe in love anymore 🤷🏾‍♀️
# ...
# @PMOIndia @RailMinIndia @PiyushGoyal @PiyushGoyalOffc :Always the trains are getting late from allahahabad/mughalsa… https://t.co/thghPOcWLH
# ...
# RT @AnjaniShahi: 2012 - Delhi to Patna - I paid ₹3929.
# 2018 - Delhi to Patna - paid ₹2421, and I receievd 10% Cash back.
#
# In 2012, I had bo…
# ...
# RT @WontStop_21: I just can’t be cool with somebody my Patna don’t fw .
# ...
# @iAaravjeet Aarvy ji white top wali ldki wohi hai....patna wali topper....
# ...

# %%
import time
from tweepy.streaming import StreamListener, Stream
class listener(StreamListener):
    def on_data(self, data):
        try:
            print(data)
            saveFile = open('twitDB.csv','a')
            saveFile.write(data)
            saveFile.write('\n')
            saveFile.close()
            return True
        except(BaseException, e):
            print('Failed data',str(e))
            time.sleep(5)
    def on_error(self, status):
        print(status)
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["hindu"])
# Out:
# {"created_at":"Mon May 28 10:59:27 +0000 2018","id":1001055343248531457,"id_str":"1001055343248531457","text":"Savarkar was an illustrious social reformer who firmly believed that political and social reforms are equally impor\u2026 https:\/\/t.co\/A28OarjuQi","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":1001036302719094785,"in_reply_to_status_id_str":"1001036302719094785","in_reply_to_user_id":53664165,"in_reply_to_user_id_str":"53664165","in_reply_to_screen_name":"shwetankbhushan","user":{"id":53664165,"id_str":"53664165","name":"Shwetank","screen_name":"shwetankbhushan","location":"India","url":"https:\/\/shwetankspad.com\/","description":"Business strategist. passionate painter, random blogger, sports fanatic, movie buff. Interested in Indian history. RTs\/Likes\/Follows\u2260endorsements.","translator_type":"none","protected":false,"verified":false,"followers_count":2069,"friends
# ...

# %%
import json as j
import pandas as pd
import matplotlib.pyplot as plt

json_data = []
with open('C:/Users/IAMLEGEND/Sample/twitter_data.json') as data_file:
    lines = data_file.readlines()
    joined_lines = "[" + ",".join(lines) + "]"

    json_data = j.loads(joined_lines)

data = pd.DataFrame(json_data)
print(data.head())
"""tweets_data = []
tweets_file = open('C:/Users/IAMLEGEND/Sample/twitter_data.txt','r')
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

print(len(tweets_data))

#Create a dataframe for data manipulation
tweets = pd.DataFrame()

#Add columns to dataframe - text,lang and country
tweets['text'] = map(lambda tweet: tweet['text'], tweets_data)
tweets['lang'] = map(lambda tweet: tweet['lang'], tweets_data)
tweets['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else None, tweets_data)

print(tweets.head(5))

tweets_by_lang = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

tweets_by_country = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='red')"""
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-3f71cc3a8589> in <module>()
#       8     joined_lines = "[" + ",".join(lines) + "]"
#       9
# ---> 10     json_data = j.loads(joined_lines)
#      11
#      12 data = pd.DataFrame(json_data)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
# ...
